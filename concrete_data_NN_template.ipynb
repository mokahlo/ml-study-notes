# %% [markdown]
# GOAL: In this assignment, we will try to predict whether the concrete quality is good or bad using Neural networks.

# %%
import numpy as np
import pandas as pd 

# Keras
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.layers import Dropout
from tensorflow.keras.optimizers import SGD, Adam, Adadelta, RMSprop
import keras.backend as K
# Train-Test
from sklearn.model_selection import train_test_split
# Scaling data
from sklearn.preprocessing import StandardScaler, LabelBinarizer
# Classification Report
from sklearn.metrics import classification_report, confusion_matrix

from keras.utils.np_utils import to_categorical

# %% [markdown]
# #### Import Data

# %% [markdown]
# #### Binarize the target label

# %% [markdown]
# #### Create X, y and scale X using Standard scaler

# %% [markdown]
# #### Split X and Y into train and test data

# %% [markdown]
# #### Train the model using Neural networks
# Hints:
# 1. Create 2-3 layers for the neural network
# 2. Use accuracy as the metric

# %% [markdown]
# #### Get predictions from the model on X_test

# %% [markdown]
# #### The model outputs probabilities. Use threshold as 0.5. If output > 0.5 then assign as class 1 else 0.

# %% [markdown]
# #### Print Confusion matrix

# %% [markdown]
# #### Print Classification report
